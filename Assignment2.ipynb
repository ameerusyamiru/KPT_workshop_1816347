# %%
path1 = 'C:/Users/user/kpt stuff/assignment2/'

# %%
import torch, torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import glob
import numpy
import random
import IPython.display as display

from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms

# %%
# Applying Transforms to the Data
import torchvision
import torchvision.transforms as transforms

image_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.GaussianBlur(kernel_size = (5,13), sigma=(0.1,0.2)),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
}

# %%
dataset = path1 +'fruit_dataset'

train_directory = os.path.join(dataset, 'train')
test_directory = os.path.join(dataset, 'validation')



# Batch size
batchSize = 32

# Number of classes
num_classes = len(os.listdir(train_directory))
print(num_classes)

# Load Data from folders
data = {
    'train': datasets.ImageFolder(root=train_directory, transform=image_transforms['train']),

    'test': datasets.ImageFolder(root=test_directory, transform=image_transforms['test'])
}

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
input_size = (3,32,32)
# Out:
# 4

# %%
train_directory
# Out:
# 'C:/Users/user/kpt stuff/assignment2/fruit_dataset\\train'

# %%
#######################################################
#                  Create Dataloader                     #
#######################################################

# Turn train and test custom Dataset's into DataLoader's
from torch.utils.data import DataLoader
trainloader = DataLoader(dataset=data['train'], # use custom created train Dataset
                                     batch_size=4, # how many samples per batch?
                                     num_workers=0, # how many subprocesses to use for data loading? (higher = more)
                                     shuffle=True) # shuffle the data?

testloader = DataLoader(dataset=data['test'], # use custom created test Dataset
                                    batch_size=4, 
                                    num_workers=0, 
                                    shuffle=False) # don't usually need to shuffle testing data

train_data_size = len(trainloader.dataset)
test_data_size = len(testloader.dataset)

print(train_data_size)
print(test_data_size)
# Out:
# 521
# 324

# %%
def train_and_validate(model, loss_criterion, optimizer, epochs=25):
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)
  
    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''
    
    start = time.time()
    history = []
    best_acc = 0.0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(trainloader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

            
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(testloader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
            
        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_test_loss = valid_loss/test_data_size 
        avg_test_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_test_loss, avg_train_acc, avg_test_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_test_loss, avg_test_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        torch.save(model, 'model_default_assign2_'+str(epoch)+'.pt')
            
    return model, history

# %%
model_ft = models.googlenet(pretrained=True)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 10.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 4)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.01)
# Out:
# C:\Users\user\anaconda3\envs\GPU\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\GPU\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=GoogLeNet_Weights.IMAGENET1K_V1`. You can also use `weights=GoogLeNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
num_epochs = 50
trained_model, history = train_and_validate(model_ft, criterion, optimizer_ft, num_epochs)
# Out:
# Epoch: 1/50
# Epoch : 000, Training: Loss: 1.4437, Accuracy: 38.1958%,
# 		Validation : Loss : 3.8045, Accuracy: 55.2469%, Time: 22.7309s
# Epoch: 2/50
# Epoch : 001, Training: Loss: 1.1783, Accuracy: 43.3781%,
# 		Validation : Loss : 5.8180, Accuracy: 16.3580%, Time: 18.0390s
# Epoch: 3/50
# Epoch : 002, Training: Loss: 1.1314, Accuracy: 40.8829%,
# 		Validation : Loss : 3.1255, Accuracy: 18.2099%, Time: 18.4325s
# Epoch: 4/50
# Epoch : 003, Training: Loss: 1.0979, Accuracy: 51.0557%,
# 		Validation : Loss : 4.5238, Accuracy: 24.0741%, Time: 18.8200s
# Epoch: 5/50
# Epoch : 004, Training: Loss: 1.0075, Accuracy: 56.0461%,
# 		Validation : Loss : 3.8110, Accuracy: 54.0123%, Time: 18.9630s
# Epoch: 6/50
# Epoch : 005, Training: Loss: 1.0072, Accuracy: 55.2783%,
# 		Validation : Loss : 2.6003, Accuracy: 40.7407%, Time: 18.9795s
# Epoch: 7/50
# Epoch : 006, Training: Loss: 0.9673, Accuracy: 60.4607%,
# 		Validation : Loss : 4.0312, Accuracy: 47.2222%, Time: 19.6760s
# Epoch: 8/50
# Epoch : 007, Training: Loss: 0.8874, Accuracy: 64.1075%,
# 		Validation : Loss : 2.6037, Accuracy: 58.0247%, Time: 19.5455s
# Epoch: 9/50
# Epoch : 008, Training: Loss: 0.9236, Accuracy: 62.3800%,
# 		Validation : Loss : 2.6110, Accuracy: 27.7778%, Time: 19.4135s
# Epoch: 10/50
# Epoch : 009, Training: Loss: 0.9067, Accuracy: 62.7639%,
# 		Validation : Loss : 2.0196, Accuracy: 36.4198%, Time: 19.7340s
# Epoch: 11/50
# Epoch : 010, Training: Loss: 0.8893, Accuracy: 64.2994%,
# 		Validation : Loss : 3.1355, Accuracy: 39.1975%, Time: 19.7115s
# Epoch: 12/50
# Epoch : 011, Training: Loss: 0.8444, Accuracy: 67.1785%,
# 		Validation : Loss : 1.9769, Accuracy: 47.8395%, Time: 20.1145s
# Epoch: 13/50
# Epoch : 012, Training: Loss: 0.8604, Accuracy: 64.2994%,
# 		Validation : Loss : 1.3536, Accuracy: 57.0988%, Time: 20.2480s
# Epoch: 14/50
# Epoch : 013, Training: Loss: 0.9007, Accuracy: 61.9962%,
# 		Validation : Loss : 1.9171, Accuracy: 58.0247%, Time: 20.6545s
# Epoch: 15/50
# Epoch : 014, Training: Loss: 0.8412, Accuracy: 65.6430%,
# 		Validation : Loss : 2.3244, Accuracy: 69.1358%, Time: 20.7750s
# Epoch: 16/50
# Epoch : 015, Training: Loss: 0.8751, Accuracy: 65.0672%,
# 		Validation : Loss : 1.5234, Accuracy: 57.0988%, Time: 20.7315s
# Epoch: 17/50
# Epoch : 016, Training: Loss: 0.8251, Accuracy: 65.8349%,
# 		Validation : Loss : 1.6475, Accuracy: 45.9877%, Time: 20.5890s
# Epoch: 18/50
# Epoch : 017, Training: Loss: 0.8254, Accuracy: 66.9866%,
# 		Validation : Loss : 2.2968, Accuracy: 72.5309%, Time: 20.9110s
# Epoch: 19/50
# Epoch : 018, Training: Loss: 0.7812, Accuracy: 69.8656%,
# 		Validation : Loss : 1.8172, Accuracy: 65.7407%, Time: 20.8935s
# Epoch: 20/50
# Epoch : 019, Training: Loss: 0.8147, Accuracy: 68.3301%,
# 		Validation : Loss : 1.3983, Accuracy: 63.8889%, Time: 20.7185s
# Epoch: 21/50
# Epoch : 020, Training: Loss: 0.7777, Accuracy: 69.6737%,
# 		Validation : Loss : 1.2508, Accuracy: 66.6667%, Time: 20.8390s
# Epoch: 22/50
# Epoch : 021, Training: Loss: 0.7603, Accuracy: 71.5931%,
# 		Validation : Loss : 1.1158, Accuracy: 72.2222%, Time: 20.7170s
# Epoch: 23/50
# Epoch : 022, Training: Loss: 0.7946, Accuracy: 69.2898%,
# 		Validation : Loss : 1.8327, Accuracy: 69.4444%, Time: 20.7720s
# Epoch: 24/50
# Epoch : 023, Training: Loss: 0.7969, Accuracy: 68.5221%,
# 		Validation : Loss : 0.9872, Accuracy: 71.2963%, Time: 20.7145s
# Epoch: 25/50
# Epoch : 024, Training: Loss: 0.7640, Accuracy: 71.5931%,
# 		Validation : Loss : 1.0433, Accuracy: 70.3704%, Time: 20.9950s
# Epoch: 26/50
# Epoch : 025, Training: Loss: 0.8186, Accuracy: 68.7140%,
# 		Validation : Loss : 1.3080, Accuracy: 68.5185%, Time: 20.6245s
# Epoch: 27/50
# Epoch : 026, Training: Loss: 0.7591, Accuracy: 69.2898%,
# 		Validation : Loss : 0.9712, Accuracy: 68.5185%, Time: 20.3160s
# Epoch: 28/50
# Epoch : 027, Training: Loss: 0.7712, Accuracy: 71.0173%,
# 		Validation : Loss : 1.0606, Accuracy: 71.6049%, Time: 20.5890s
# Epoch: 29/50
# Epoch : 028, Training: Loss: 0.7406, Accuracy: 72.1689%,
# 		Validation : Loss : 1.2419, Accuracy: 66.6667%, Time: 20.1915s
# Epoch: 30/50
# Epoch : 029, Training: Loss: 0.7242, Accuracy: 72.1689%,
# 		Validation : Loss : 1.1207, Accuracy: 71.9136%, Time: 20.1810s
# Epoch: 31/50
# Epoch : 030, Training: Loss: 0.6780, Accuracy: 72.9367%,
# 		Validation : Loss : 2.4777, Accuracy: 45.0617%, Time: 21.0065s
# Epoch: 32/50
# Epoch : 031, Training: Loss: 0.7210, Accuracy: 71.5931%,
# 		Validation : Loss : 17.9962, Accuracy: 30.2469%, Time: 21.0435s
# Epoch: 33/50
# Epoch : 032, Training: Loss: 0.6771, Accuracy: 74.4722%,
# 		Validation : Loss : 2.5577, Accuracy: 50.6173%, Time: 20.4160s
# Epoch: 34/50
# Epoch : 033, Training: Loss: 0.6833, Accuracy: 73.8964%,
# 		Validation : Loss : 1.2841, Accuracy: 69.1358%, Time: 20.2285s
# Epoch: 35/50
# Epoch : 034, Training: Loss: 0.6655, Accuracy: 74.0883%,
# 		Validation : Loss : 3.3594, Accuracy: 50.6173%, Time: 20.6220s
# Epoch: 36/50
# Epoch : 035, Training: Loss: 0.7170, Accuracy: 73.8964%,
# 		Validation : Loss : 1.4654, Accuracy: 70.6790%, Time: 20.6595s
# Epoch: 37/50
# Epoch : 036, Training: Loss: 0.7140, Accuracy: 72.7447%,
# 		Validation : Loss : 2.1226, Accuracy: 60.8025%, Time: 20.6515s
# Epoch: 38/50
# Epoch : 037, Training: Loss: 0.7146, Accuracy: 72.5528%,
# 		Validation : Loss : 1.4984, Accuracy: 72.2222%, Time: 20.4455s
# Epoch: 39/50
# Epoch : 038, Training: Loss: 0.6466, Accuracy: 75.8157%,
# 		Validation : Loss : 1.4247, Accuracy: 67.9012%, Time: 20.3240s
# Epoch: 40/50
# Epoch : 039, Training: Loss: 0.6768, Accuracy: 75.0480%,
# 		Validation : Loss : 2.5635, Accuracy: 41.6667%, Time: 20.6125s
# Epoch: 41/50
# Epoch : 040, Training: Loss: 0.6307, Accuracy: 76.0077%,
# 		Validation : Loss : 1.2574, Accuracy: 72.5309%, Time: 20.4820s
# Epoch: 42/50
# Epoch : 041, Training: Loss: 0.6782, Accuracy: 74.0883%,
# 		Validation : Loss : 2.1504, Accuracy: 38.5802%, Time: 20.4140s
# Epoch: 43/50
# Epoch : 042, Training: Loss: 0.7106, Accuracy: 72.1689%,
# 		Validation : Loss : 1.0056, Accuracy: 71.9136%, Time: 20.7695s
# Epoch: 44/50
# Epoch : 043, Training: Loss: 0.6963, Accuracy: 73.3205%,
# 		Validation : Loss : 1.0389, Accuracy: 69.1358%, Time: 20.4195s
# Epoch: 45/50
# Epoch : 044, Training: Loss: 0.6974, Accuracy: 73.5125%,
# 		Validation : Loss : 1.0820, Accuracy: 73.7654%, Time: 20.8485s
# Epoch: 46/50
# Epoch : 045, Training: Loss: 0.6631, Accuracy: 75.0480%,
# 		Validation : Loss : 1.1525, Accuracy: 68.5185%, Time: 20.5335s
# Epoch: 47/50
# Epoch : 046, Training: Loss: 0.6708, Accuracy: 73.3205%,
# 		Validation : Loss : 1.4826, Accuracy: 68.8272%, Time: 20.4395s
# Epoch: 48/50
# Epoch : 047, Training: Loss: 0.6370, Accuracy: 76.9674%,
# 		Validation : Loss : 1.0712, Accuracy: 68.5185%, Time: 20.6400s
# Epoch: 49/50
# Epoch : 048, Training: Loss: 0.6560, Accuracy: 75.4319%,
# 		Validation : Loss : 1.0812, Accuracy: 65.1235%, Time: 20.7755s
# Epoch: 50/50
# Epoch : 049, Training: Loss: 0.6579, Accuracy: 77.9271%,
# 		Validation : Loss : 1.5147, Accuracy: 70.0617%, Time: 20.1195s

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
# Analyze the loss curve

history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0,3)
# plt.savefig('cifar10_loss_curve.png')
plt.show()

# %%
#Analyze the accuracy curve

plt.plot(history[:,2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0,1)
# plt.savefig('cifar10_accuracy_curve.png')
plt.show()

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in os.listdir(train_directory)}
total_pred = {classname: 0 for classname in os.listdir(train_directory)}

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
#         images = images.view(images.size(0), -1)
        outputs = model_ft(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[os.listdir(train_directory)[label]] += 1
            total_pred[os.listdir(train_directory)[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Accuracy for class: durian is 0.0 %
# Accuracy for class: pumpkin is 94.0 %
# Accuracy for class: tomato is 82.0 %
# Accuracy for class: watermelon is 79.4 %

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

y_pred = []
y_true = []

model_ft.to('cpu')

# iterate over test data
for inputs, labels in testloader:
#         #reshape images so they can be fed to a nn.Linear()
#         inputs = inputs.view(inputs.size(0), -1)
        output = model_ft(inputs) # Feed Network

        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output) # Save Prediction
        
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) # Save Truth

# constant for classes
classes = ('durian', 'pumpkin', 'tomato', 'watermelon')

# Build confusion matrix
cf_matrix = confusion_matrix(y_true, y_pred)
df_cm = pd.DataFrame(cf_matrix/np.sum(cf_matrix) *10, index = [i for i in classes],
                     columns = [i for i in classes])
plt.figure(figsize = (20,10))
sn.heatmap(df_cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
#  The training of the model on the dataset after modification to improve the performance of the model.

# %%
dataset = path1 +'/fruit_dataset_v1'

train_directory = os.path.join(dataset, 'train')
test_directory = os.path.join(dataset, 'validation')

# Batch size
batchSize = 32

# Number of classes
num_classes = len(os.listdir(train_directory))
print(num_classes)

# Load Data from folders
data = {
    'train': datasets.ImageFolder(root=train_directory, transform=image_transforms['train']),

    'test': datasets.ImageFolder(root=test_directory, transform=image_transforms['test'])
}

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Out:
# 4

# %%
#######################################################
#                  Create Dataloader                     #
#######################################################

# Turn train and test custom Dataset's into DataLoader's
from torch.utils.data import DataLoader
trainloader = DataLoader(dataset=data['train'], # use custom created train Dataset
                                     batch_size=4, # how many samples per batch?
                                     num_workers=0, # how many subprocesses to use for data loading? (higher = more)
                                     shuffle=True) # shuffle the data?

testloader = DataLoader(dataset=data['test'], # use custom created test Dataset
                                    batch_size=4, 
                                    num_workers=0, 
                                    shuffle=False) # don't usually need to shuffle testing data

train_data_size = len(trainloader.dataset)
test_data_size = len(testloader.dataset)

print(train_data_size)
print(test_data_size)
# Out:
# 1604
# 199

# %%
def train_and_validate(model, loss_criterion, optimizer, epochs=25):
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)
  
    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''
    
    start = time.time()
    history = []
    best_acc = 0.0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(trainloader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

            
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(testloader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
            
        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_test_loss = valid_loss/test_data_size 
        avg_test_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_test_loss, avg_train_acc, avg_test_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_test_loss, avg_test_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        torch.save(model, 'model_default_assign2_'+str(epoch)+'.pt')
            
    return model, history

# %%
model_ft = models.googlenet(pretrained=True)
num_ftrs = model_ft.fc.in_features

for module,param in zip(model_ft.modules(), model_ft.parameters()):
  if isinstance(module, nn.BatchNorm2d):
    param.requires_grad = False

model_ft.fc = nn.Sequential(nn.Linear(num_ftrs, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.25),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.25),
            nn.Linear(64, num_classes))
 
model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.0001)

# %%
num_epochs = 40
trained_model, history = train_and_validate(model_ft, criterion, optimizer_ft, num_epochs)
# Out:
# Epoch: 1/40
# Epoch : 000, Training: Loss: 0.0756, Accuracy: 97.8180%,
# 		Validation : Loss : 0.3027, Accuracy: 90.9548%, Time: 54.7210s
# Epoch: 2/40
# Epoch : 001, Training: Loss: 0.0481, Accuracy: 98.5661%,
# 		Validation : Loss : 0.3410, Accuracy: 89.9497%, Time: 55.3980s
# Epoch: 3/40
# Epoch : 002, Training: Loss: 0.0821, Accuracy: 97.7556%,
# 		Validation : Loss : 0.1915, Accuracy: 91.9598%, Time: 52.8965s
# Epoch: 4/40
# Epoch : 003, Training: Loss: 0.0728, Accuracy: 98.0673%,
# 		Validation : Loss : 0.2043, Accuracy: 94.4724%, Time: 52.8780s
# Epoch: 5/40
# Epoch : 004, Training: Loss: 0.0652, Accuracy: 98.1920%,
# 		Validation : Loss : 0.2155, Accuracy: 93.4673%, Time: 53.0275s
# Epoch: 6/40
# Epoch : 005, Training: Loss: 0.0482, Accuracy: 98.5037%,
# 		Validation : Loss : 0.2932, Accuracy: 93.4673%, Time: 52.7870s
# Epoch: 7/40
# Epoch : 006, Training: Loss: 0.0519, Accuracy: 98.5661%,
# 		Validation : Loss : 0.1538, Accuracy: 95.4774%, Time: 52.8085s
# Epoch: 8/40
# Epoch : 007, Training: Loss: 0.0383, Accuracy: 98.7531%,
# 		Validation : Loss : 0.2664, Accuracy: 92.9648%, Time: 53.1500s
# Epoch: 9/40
# Epoch : 008, Training: Loss: 0.0451, Accuracy: 98.7531%,
# 		Validation : Loss : 0.1170, Accuracy: 96.4824%, Time: 54.4705s
# Epoch: 10/40
# Epoch : 009, Training: Loss: 0.0248, Accuracy: 99.2519%,
# 		Validation : Loss : 0.2620, Accuracy: 94.4724%, Time: 56.4995s
# Epoch: 11/40
# Epoch : 010, Training: Loss: 0.0654, Accuracy: 98.0050%,
# 		Validation : Loss : 0.2296, Accuracy: 94.9749%, Time: 54.8185s
# Epoch: 12/40
# Epoch : 011, Training: Loss: 0.0643, Accuracy: 98.1920%,
# 		Validation : Loss : 0.1259, Accuracy: 95.9799%, Time: 54.6970s
# Epoch: 13/40
# Epoch : 012, Training: Loss: 0.0474, Accuracy: 98.6284%,
# 		Validation : Loss : 0.2420, Accuracy: 93.9698%, Time: 54.9780s
# Epoch: 14/40
# Epoch : 013, Training: Loss: 0.0227, Accuracy: 99.4389%,
# 		Validation : Loss : 0.1852, Accuracy: 94.9749%, Time: 55.6605s
# Epoch: 15/40
# Epoch : 014, Training: Loss: 0.0370, Accuracy: 99.0025%,
# 		Validation : Loss : 0.1426, Accuracy: 96.4824%, Time: 55.4545s
# Epoch: 16/40
# Epoch : 015, Training: Loss: 0.0300, Accuracy: 99.3142%,
# 		Validation : Loss : 0.2019, Accuracy: 95.9799%, Time: 55.4685s
# Epoch: 17/40
# Epoch : 016, Training: Loss: 0.0221, Accuracy: 99.2519%,
# 		Validation : Loss : 0.2142, Accuracy: 95.4774%, Time: 54.9215s
# Epoch: 18/40
# Epoch : 017, Training: Loss: 0.0267, Accuracy: 99.3142%,
# 		Validation : Loss : 0.1497, Accuracy: 95.9799%, Time: 55.6370s
# Epoch: 19/40
# Epoch : 018, Training: Loss: 0.0299, Accuracy: 99.3142%,
# 		Validation : Loss : 0.2127, Accuracy: 94.4724%, Time: 55.1470s
# Epoch: 20/40
# Epoch : 019, Training: Loss: 0.0334, Accuracy: 99.0025%,
# 		Validation : Loss : 0.1925, Accuracy: 93.4673%, Time: 55.1685s
# Epoch: 21/40
# Epoch : 020, Training: Loss: 0.0615, Accuracy: 98.3167%,
# 		Validation : Loss : 0.4514, Accuracy: 87.9397%, Time: 55.1800s
# Epoch: 22/40
# Epoch : 021, Training: Loss: 0.0517, Accuracy: 98.6284%,
# 		Validation : Loss : 0.2509, Accuracy: 93.4673%, Time: 55.2470s
# Epoch: 23/40
# Epoch : 022, Training: Loss: 0.0263, Accuracy: 99.3142%,
# 		Validation : Loss : 0.1944, Accuracy: 94.9749%, Time: 54.9600s
# Epoch: 24/40
# Epoch : 023, Training: Loss: 0.0255, Accuracy: 99.1272%,
# 		Validation : Loss : 0.2043, Accuracy: 95.4774%, Time: 55.5175s
# Epoch: 25/40
# Epoch : 024, Training: Loss: 0.0209, Accuracy: 99.3766%,
# 		Validation : Loss : 0.2519, Accuracy: 94.4724%, Time: 55.2290s
# Epoch: 26/40
# Epoch : 025, Training: Loss: 0.0338, Accuracy: 98.8155%,
# 		Validation : Loss : 0.1445, Accuracy: 96.4824%, Time: 56.0745s
# Epoch: 27/40
# Epoch : 026, Training: Loss: 0.0148, Accuracy: 99.6883%,
# 		Validation : Loss : 0.1645, Accuracy: 94.9749%, Time: 56.2280s
# Epoch: 28/40
# Epoch : 027, Training: Loss: 0.0057, Accuracy: 99.7506%,
# 		Validation : Loss : 0.2672, Accuracy: 92.9648%, Time: 55.6065s
# Epoch: 29/40
# Epoch : 028, Training: Loss: 0.0077, Accuracy: 99.8130%,
# 		Validation : Loss : 0.8703, Accuracy: 87.4372%, Time: 54.8645s
# Epoch: 30/40
# Epoch : 029, Training: Loss: 0.0423, Accuracy: 99.0025%,
# 		Validation : Loss : 0.1262, Accuracy: 96.4824%, Time: 55.0145s
# Epoch: 31/40
# Epoch : 030, Training: Loss: 0.0142, Accuracy: 99.6259%,
# 		Validation : Loss : 0.2202, Accuracy: 94.9749%, Time: 54.5595s
# Epoch: 32/40
# Epoch : 031, Training: Loss: 0.0510, Accuracy: 98.6284%,
# 		Validation : Loss : 0.2288, Accuracy: 93.4673%, Time: 55.4930s
# Epoch: 33/40
# Epoch : 032, Training: Loss: 0.0146, Accuracy: 99.6259%,
# 		Validation : Loss : 0.3054, Accuracy: 92.9648%, Time: 56.9365s
# Epoch: 34/40
# Epoch : 033, Training: Loss: 0.0066, Accuracy: 99.8753%,
# 		Validation : Loss : 0.2588, Accuracy: 94.4724%, Time: 54.8435s
# Epoch: 35/40
# Epoch : 034, Training: Loss: 0.0008, Accuracy: 100.0000%,
# 		Validation : Loss : 0.2967, Accuracy: 92.4623%, Time: 54.8805s
# Epoch: 36/40
# Epoch : 035, Training: Loss: 0.0489, Accuracy: 98.9401%,
# 		Validation : Loss : 0.2362, Accuracy: 93.4673%, Time: 57.4630s
# Epoch: 37/40
# Epoch : 036, Training: Loss: 0.0066, Accuracy: 99.6259%,
# 		Validation : Loss : 0.1611, Accuracy: 95.9799%, Time: 57.8500s
# Epoch: 38/40
# Epoch : 037, Training: Loss: 0.0202, Accuracy: 99.4389%,
# 		Validation : Loss : 0.1377, Accuracy: 96.9849%, Time: 55.0900s
# Epoch: 39/40
# Epoch : 038, Training: Loss: 0.0320, Accuracy: 99.1895%,
# 		Validation : Loss : 0.2393, Accuracy: 95.4774%, Time: 54.5430s
# Epoch: 40/40
# Epoch : 039, Training: Loss: 0.0493, Accuracy: 98.8155%,
# 		Validation : Loss : 0.2666, Accuracy: 93.4673%, Time: 55.6700s

# %%
history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.title('Loss vs Epoch')
plt.ylim(0,3)
plt.show()

# %%
plt.plot(history[:,2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Epoch')
plt.ylim(0,1)
plt.show()

# %%
correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in testloader:
#         images, labels = data
        images, labels = data[0].to(device), data[1].to(device)
        # calculate outputs by running images through the network
#         images = images.view(images.size(0), -1)
        outputs = model_ft(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of the network: {100 * correct // total} %')
# Out:
# Accuracy of the network: 93 %

# %%
correct_pred = {classname: 0 for classname in os.listdir(train_directory)}
total_pred = {classname: 0 for classname in os.listdir(train_directory)}

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
#         images = images.view(images.size(0), -1)
        outputs = model_ft(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[os.listdir(train_directory)[label]] += 1
            total_pred[os.listdir(train_directory)[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Accuracy for class: durian is 95.9 %
# Accuracy for class: pumpkin is 98.0 %
# Accuracy for class: tomato is 94.0 %
# Accuracy for class: watermelon is 86.0 %

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

y_pred = []
y_true = []

model_ft.to('cpu')

# iterate over test data
for inputs, labels in testloader:
#         #reshape images so they can be fed to a nn.Linear()
#         inputs = inputs.view(inputs.size(0), -1)
        output = model_ft(inputs) # Feed Network

        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output) # Save Prediction
        
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) # Save Truth

# constant for classes
classes = ('durian', 'pumpkin', 'tomato', 'watermelon')

# Build confusion matrix
cf_matrix = confusion_matrix(y_true, y_pred)
df_cm = pd.DataFrame(cf_matrix/np.sum(cf_matrix) *10, index = [i for i in classes],
                     columns = [i for i in classes])
plt.figure(figsize = (20,10))
sn.heatmap(df_cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
save_path = 'C:/Users/user/kpt stuff/assignment2/model_default_assign2_39.pt'
torch.save(model_ft.state_dict(), save_path)

# %%
#Inferencing using the model

# %%
classes = ["Durian","Pumpkin","Tomato","Watermelon",]

# %%
model_ft.load_state_dict(torch.load('C:/Users/user/kpt stuff/assignment2/model_default_assign2_39.pt'))
the_model = model_ft.eval()

# %%
mean = [0.4363, 0.4328, 0.3291]
std = [0.2129, 0.2075, 0.2038]

image_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(torch.Tensor(mean), torch.Tensor(std))
])

# %%
def classify(the_model, image_transforms, image_path, classes):
    model = the_model
    image = Image.open(image_path)
    image = image_transforms(image).float()
    image = image.unsqueeze(0)
    
    output = model(image)
    _, predicted = torch.max(output.data, 1)
    
    return(classes[predicted.item()])

# %%
plt.figure(figsize=[20,20])
name = classify(the_model, image_transforms, 'C:/Users/user/kpt stuff/assignment2/durian test.jpg', classes)
img1 = Image.open('C:/Users/user/kpt stuff/assignment2/durian test.jpg')
plt.subplot(141);plt.imshow(img1);plt.title(name)
plt.show()

plt.figure(figsize=[20,20])
name = classify(the_model, image_transforms, 'C:/Users/user/kpt stuff/assignment2/tomato test.jpg', classes)
img2 = Image.open('C:/Users/user/kpt stuff/assignment2/tomato test.jpg')
plt.subplot(142);plt.imshow(img2);plt.title(name)
plt.show()

plt.figure(figsize=[20,20])
name = classify(the_model, image_transforms, 'C:/Users/user/kpt stuff/assignment2/watermelon test.jpg', classes)
img3 = Image.open('C:/Users/user/kpt stuff/assignment2/watermelon test.jpg')
plt.subplot(143);plt.imshow(img3);plt.title(name)
plt.show()

plt.figure(figsize=[20,20])
name = classify(the_model, image_transforms, 'C:/Users/user/kpt stuff/assignment2/pumpkin test.jpg', classes)
img4 = Image.open('C:/Users/user/kpt stuff/assignment2/pumpkin test.jpg')
plt.subplot(144);plt.imshow(img4);plt.title(name)
plt.show()
